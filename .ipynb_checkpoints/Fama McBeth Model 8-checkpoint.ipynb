# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os
import pickle
import matplotlib.pyplot as plt
import statsmodels.api as sm
# Out:
# /home/harshit/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
eq_list = os.listdir("/home/harshit/Project/ent_models/")
eq_list = pd.DataFrame(eq_list,columns=["Equities"])
for i in eq_list["Equities"]:
    symbol=i.split('.')[0]
    model1 = pickle.load(open("/home/harshit/Project/ent_models/"+i,'rb'))
    model2 = pickle.load(open("/home/harshit/Project/car_models/"+i,'rb'))
    equity = pd.read_csv("/home/harshit/Project/Returns/all_ret_by_company/"+symbol+".csv")
    equity=equity.drop([0])
    equity.Date = equity.Date.apply(lambda x: x.replace("-",""))
    equity["Date"] = equity["Date"].apply(pd.to_numeric)
    factors = pd.read_csv("/home/harshit/Project/allfactors.csv")
    all_data = pd.merge(factors,equity,on="Date")
    symbol = i.split('.')[0]  #Removing ".csv" to get file name
    all_data.rename(columns={'Return':symbol}, inplace=True)
    X1= all_data[["SMB %","HML %","WML %","Rm-Rf %","high-low"]] #Making X variable for entropy included model
    X2 = all_data[["SMB %","HML %","WML %","Rm-Rf %"]] #Making X variable for Carhart 4 factor model
    Y = all_data[[symbol]]

# %%
model1 = pickle.load(open("/home/harshit/Project/ent_models/VETO.sav",'rb'))

# %%
previous_entropy = pd.read_csv("/home/harshit/Project/2012/entropy.csv")
return_path = "/home/harshit/Project/Returns/combined/"
returns = pd.read_csv(return_path+"combined2013.csv")

# %%
date = pd.DataFrame(pd.to_datetime(returns["Date"]))
ret_ent = date
for i in previous_entropy["Symbol"]:
    name = i+".csv"
    if name in returns:
        ret = pd.DataFrame(returns[i+".csv"])
        ret = date.merge(ret,left_index=True, right_index=True)
        #ret["Date"] = pd.to_datetime(high["Date"])
        ret_ent = pd.merge_asof(ret_ent,ret,on="Date")

# %%
high_ent = ret_ent.iloc[:,0:31]
low_ent = ret_ent.iloc[:,-30:]
low_ent = pd.merge(date,low_ent,left_index=True,right_index=True)

# %%
low_ent
# Out:
#           Date  NELCAST.csv    KEI.csv  METKORE.csv  SUNFLAG.csv  JKPAPER.csv  \
# 0   2013-01-01     0.000000   0.000000     0.000000     0.000000     0.000000
# 1   2013-01-02    -1.268499  -1.166181     1.418440    -2.291667    -0.377358
# 2   2013-01-03    -0.626305   0.864553     2.517986    -9.368635     0.250627
# 3   2013-01-04     0.829876   0.581395    11.439114     1.117318     0.251256
# 4   2013-01-07     0.418410  -1.461988    -3.333333    -1.506591    -0.629723
# 5   2013-01-08     0.000000   0.864553     0.000000     3.710575     1.376721
# 6   2013-01-09     1.050420   0.290698    -0.806452     6.551060     0.126904
# 7   2013-01-10     0.636943   1.457726     2.000000     4.329897     0.762389
# 8   2013-01-11     0.213675   1.479290     0.816327     1.724138     1.664533
# 9   2013-01-14     1.284797   0.300300     0.823045     0.000000     0.260417
# 10  2013-01-15     0.650759  -1.506024    -1.659751     0.219298    -1.436031
# ...

# %%
previous_entropy[""]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'KEI'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-9939dd4def9c> in <module>()
# ----> 1 previous_entropy["KEI"]
#
# ...
